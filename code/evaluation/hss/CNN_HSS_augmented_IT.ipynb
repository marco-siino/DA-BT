# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/DA-BT/blob/main/code/evaluation/hss/CNN_HSS_augmented_IT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Investigating text data augmentation using back translation for author profiling
# - - -
# CNN ON HSS DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Hate Speech Spreaders Dataset augmented with IT backtranslation.
# Code by M. Siino.
#
# From the paper: "Investigating text data augmentation using back translation for author profiling" by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf
from urllib import request


import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# Import class Dataset
module_url = f"https://raw.githubusercontent.com/marco-siino/DA-BT/main/code/dataset.py"
module_name = module_url.split('/')[-1]
print(f'Fetching {module_url}')
with request.urlopen(module_url) as f, open(module_name,'w') as outf:
  a = f.read()
  outf.write(a.decode('utf-8'))
from dataset import Dataset

# Import class Vectorizer
module_url = f"https://raw.githubusercontent.com/marco-siino/DA-BT/main/code/vectorizer.py"
module_name = module_url.split('/')[-1]
print(f'Fetching {module_url}')
with request.urlopen(module_url) as f, open(module_name,'w') as outf:
  a = f.read()
  outf.write(a.decode('utf-8'))
from vectorizer import Vectorizer

# Import class Simulator
module_url = f"https://raw.githubusercontent.com/marco-siino/DA-BT/main/code/simulator.py"
module_name = module_url.split('/')[-1]
print(f'Fetching {module_url}')
with request.urlopen(module_url) as f, open(module_name,'w') as outf:
  a = f.read()
  outf.write(a.decode('utf-8'))
from simulator import Simulator
# Out:
# Fetching https://raw.githubusercontent.com/marco-siino/DA-BT/main/code/dataset.py
# Fetching https://raw.githubusercontent.com/marco-siino/DA-BT/main/code/vectorizer.py
# Fetching https://raw.githubusercontent.com/marco-siino/DA-BT/main/code/simulator.py

# %% [markdown]
# ## Fetch the dataset zips from GitHub and build up a Keras DS.

# %%
# Parameters of Dataset object are name of the ds used and augmentation language used.
ds = Dataset('hss','it')
ds.build_ds(1)
# Out:
# Downloading data from https://github.com/marco-siino/DA-BT/raw/main/data/hss/hss-train-it.zip
# 1935633/1935633 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-BT/raw/main/data/hss/hss-test-it.zip
# 1023093/1023093 [==============================] - 0s 0us/step
# Found 200 files belonging to 2 classes.
# Found 100 files belonging to 2 classes.

# %% [markdown]
# ## Vectorize text accordingly to the train set.

# %%
vct_layer_obj = Vectorizer(ds.train_set)
# Out:
# Length of the longest sample is: 8556
#
# Vocabulary size is: 72630

# %% [markdown]
# ## Run the simulation.

# %%
simulator = Simulator ("cnn",5,20,ds.train_set,ds.test_set,vct_layer_obj.vectorize_layer)
simulator.run()
# Out:
# Setup for shallow model completed.
# 200/200 [==============================] - 44s 161ms/step - loss: 0.7063 - binary_accuracy: 0.4500 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test set at epoch  0  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6963 - binary_accuracy: 0.4250 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test set at epoch  1  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6952 - binary_accuracy: 0.4150 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test set at epoch  2  is:  0.5
#
# 200/200 [==============================] - 4s 18ms/step - loss: 0.6949 - binary_accuracy: 0.4500 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test set at epoch  3  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6947 - binary_accuracy: 0.4500 - val_loss: 0.6927 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test set at epoch  4  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6931 - binary_accuracy: 0.4900 - val_loss: 0.6894 - val_binary_accuracy: 0.5700
# Run:  1 / Accuracy on test set at epoch  5  is:  0.5699999928474426
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6833 - binary_accuracy: 0.5450 - val_loss: 0.6823 - val_binary_accuracy: 0.5600
# Run:  1 / Accuracy on test set at epoch  6  is:  0.5600000023841858
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6591 - binary_accuracy: 0.5900 - val_loss: 0.6824 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy on test set at epoch  7  is:  0.5799999833106995
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6173 - binary_accuracy: 0.6800 - val_loss: 0.6734 - val_binary_accuracy: 0.6000
# Run:  1 / Accuracy on test set at epoch  8  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.5471 - binary_accuracy: 0.7550 - val_loss: 0.6601 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy on test set at epoch  9  is:  0.5799999833106995
#
# 200/200 [==============================] - 4s 18ms/step - loss: 0.4301 - binary_accuracy: 0.8250 - val_loss: 0.7003 - val_binary_accuracy: 0.6100
# Run:  1 / Accuracy on test set at epoch  10  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.2795 - binary_accuracy: 0.8600 - val_loss: 0.7924 - val_binary_accuracy: 0.6400
# Run:  1 / Accuracy on test set at epoch  11  is:  0.6399999856948853
#
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1881 - binary_accuracy: 0.9250 - val_loss: 0.8333 - val_binary_accuracy: 0.6100
# Run:  1 / Accuracy on test set at epoch  12  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1073 - binary_accuracy: 0.9600 - val_loss: 1.1012 - val_binary_accuracy: 0.6300
# Run:  1 / Accuracy on test set at epoch  13  is:  0.6299999952316284
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0607 - binary_accuracy: 0.9750 - val_loss: 1.2369 - val_binary_accuracy: 0.6000
# Run:  1 / Accuracy on test set at epoch  14  is:  0.6000000238418579
#
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0226 - binary_accuracy: 0.9950 - val_loss: 1.6906 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy on test set at epoch  15  is:  0.5799999833106995
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0158 - binary_accuracy: 0.9950 - val_loss: 1.7888 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy on test set at epoch  16  is:  0.5799999833106995
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0079 - binary_accuracy: 0.9950 - val_loss: 1.5826 - val_binary_accuracy: 0.5900
# Run:  1 / Accuracy on test set at epoch  17  is:  0.5899999737739563
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0014 - binary_accuracy: 1.0000 - val_loss: 1.5591 - val_binary_accuracy: 0.6800
# Run:  1 / Accuracy on test set at epoch  18  is:  0.6800000071525574
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0041 - binary_accuracy: 1.0000 - val_loss: 1.8247 - val_binary_accuracy: 0.6000
# Run:  1 / Accuracy on test set at epoch  19  is:  0.6000000238418579
#
# Accuracies over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5699999928474426, 0.5600000023841858, 0.5799999833106995, 0.6000000238418579, 0.5799999833106995, 0.6100000143051147, 0.6399999856948853, 0.6100000143051147, 0.6299999952316284, 0.6000000238418579, 0.5799999833106995, 0.5799999833106995, 0.5899999737739563, 0.6800000071525574, 0.6000000238418579]
#
# 200/200 [==============================] - 25s 117ms/step - loss: 0.7064 - binary_accuracy: 0.4400 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test set at epoch  0  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6965 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test set at epoch  1  is:  0.5
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.6956 - binary_accuracy: 0.4050 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test set at epoch  2  is:  0.5
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6953 - binary_accuracy: 0.4150 - val_loss: 0.6931 - val_binary_accuracy: 0.5200
# Run:  2 / Accuracy on test set at epoch  3  is:  0.5199999809265137
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6946 - binary_accuracy: 0.4400 - val_loss: 0.6929 - val_binary_accuracy: 0.5500
# Run:  2 / Accuracy on test set at epoch  4  is:  0.550000011920929
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6933 - binary_accuracy: 0.4950 - val_loss: 0.6905 - val_binary_accuracy: 0.5300
# Run:  2 / Accuracy on test set at epoch  5  is:  0.5299999713897705
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6867 - binary_accuracy: 0.5300 - val_loss: 0.6834 - val_binary_accuracy: 0.5500
# Run:  2 / Accuracy on test set at epoch  6  is:  0.550000011920929
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.6658 - binary_accuracy: 0.5700 - val_loss: 0.6879 - val_binary_accuracy: 0.5600
# Run:  2 / Accuracy on test set at epoch  7  is:  0.5600000023841858
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6256 - binary_accuracy: 0.6600 - val_loss: 0.6870 - val_binary_accuracy: 0.5800
# Run:  2 / Accuracy on test set at epoch  8  is:  0.5799999833106995
#
# 200/200 [==============================] - 4s 18ms/step - loss: 0.5611 - binary_accuracy: 0.7550 - val_loss: 0.6660 - val_binary_accuracy: 0.6100
# Run:  2 / Accuracy on test set at epoch  9  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.4650 - binary_accuracy: 0.8150 - val_loss: 0.6783 - val_binary_accuracy: 0.6300
# Run:  2 / Accuracy on test set at epoch  10  is:  0.6299999952316284
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.3108 - binary_accuracy: 0.8600 - val_loss: 0.7769 - val_binary_accuracy: 0.6200
# Run:  2 / Accuracy on test set at epoch  11  is:  0.6200000047683716
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.2195 - binary_accuracy: 0.9200 - val_loss: 0.8216 - val_binary_accuracy: 0.6100
# Run:  2 / Accuracy on test set at epoch  12  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.1053 - binary_accuracy: 0.9500 - val_loss: 0.9354 - val_binary_accuracy: 0.6400
# Run:  2 / Accuracy on test set at epoch  13  is:  0.6399999856948853
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0685 - binary_accuracy: 0.9600 - val_loss: 1.3116 - val_binary_accuracy: 0.6000
# Run:  2 / Accuracy on test set at epoch  14  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0136 - binary_accuracy: 1.0000 - val_loss: 1.7106 - val_binary_accuracy: 0.5900
# Run:  2 / Accuracy on test set at epoch  15  is:  0.5899999737739563
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0096 - binary_accuracy: 0.9950 - val_loss: 1.9073 - val_binary_accuracy: 0.5600
# Run:  2 / Accuracy on test set at epoch  16  is:  0.5600000023841858
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0039 - binary_accuracy: 1.0000 - val_loss: 2.0613 - val_binary_accuracy: 0.5800
# Run:  2 / Accuracy on test set at epoch  17  is:  0.5799999833106995
#
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0025 - binary_accuracy: 1.0000 - val_loss: 2.5911 - val_binary_accuracy: 0.5800
# Run:  2 / Accuracy on test set at epoch  18  is:  0.5799999833106995
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0037 - binary_accuracy: 1.0000 - val_loss: 2.4148 - val_binary_accuracy: 0.5800
# Run:  2 / Accuracy on test set at epoch  19  is:  0.5799999833106995
#
# Accuracies over epochs: [0.5, 0.5, 0.5, 0.5199999809265137, 0.550000011920929, 0.5299999713897705, 0.550000011920929, 0.5600000023841858, 0.5799999833106995, 0.6100000143051147, 0.6299999952316284, 0.6200000047683716, 0.6100000143051147, 0.6399999856948853, 0.6000000238418579, 0.5899999737739563, 0.5600000023841858, 0.5799999833106995, 0.5799999833106995, 0.5799999833106995]
#
# 200/200 [==============================] - 24s 114ms/step - loss: 0.7054 - binary_accuracy: 0.4600 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test set at epoch  0  is:  0.5
#
# 200/200 [==============================] - 4s 18ms/step - loss: 0.6967 - binary_accuracy: 0.4050 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test set at epoch  1  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6952 - binary_accuracy: 0.4300 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test set at epoch  2  is:  0.5
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.6950 - binary_accuracy: 0.4250 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test set at epoch  3  is:  0.5
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6948 - binary_accuracy: 0.4050 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test set at epoch  4  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6944 - binary_accuracy: 0.4700 - val_loss: 0.6927 - val_binary_accuracy: 0.5500
# Run:  3 / Accuracy on test set at epoch  5  is:  0.550000011920929
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6925 - binary_accuracy: 0.4950 - val_loss: 0.6891 - val_binary_accuracy: 0.5900
# Run:  3 / Accuracy on test set at epoch  6  is:  0.5899999737739563
#
# 200/200 [==============================] - 4s 20ms/step - loss: 0.6829 - binary_accuracy: 0.5350 - val_loss: 0.6828 - val_binary_accuracy: 0.5800
# Run:  3 / Accuracy on test set at epoch  7  is:  0.5799999833106995
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6600 - binary_accuracy: 0.5650 - val_loss: 0.6858 - val_binary_accuracy: 0.5700
# Run:  3 / Accuracy on test set at epoch  8  is:  0.5699999928474426
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6201 - binary_accuracy: 0.6800 - val_loss: 0.6802 - val_binary_accuracy: 0.5900
# Run:  3 / Accuracy on test set at epoch  9  is:  0.5899999737739563
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.5549 - binary_accuracy: 0.7550 - val_loss: 0.6655 - val_binary_accuracy: 0.6100
# Run:  3 / Accuracy on test set at epoch  10  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.4533 - binary_accuracy: 0.8150 - val_loss: 0.6763 - val_binary_accuracy: 0.6300
# Run:  3 / Accuracy on test set at epoch  11  is:  0.6299999952316284
#
# 200/200 [==============================] - 4s 18ms/step - loss: 0.3264 - binary_accuracy: 0.8550 - val_loss: 0.7694 - val_binary_accuracy: 0.6200
# Run:  3 / Accuracy on test set at epoch  12  is:  0.6200000047683716
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.1975 - binary_accuracy: 0.9200 - val_loss: 0.9106 - val_binary_accuracy: 0.6300
# Run:  3 / Accuracy on test set at epoch  13  is:  0.6299999952316284
#
# 200/200 [==============================] - 4s 18ms/step - loss: 0.1301 - binary_accuracy: 0.9450 - val_loss: 1.0290 - val_binary_accuracy: 0.6400
# Run:  3 / Accuracy on test set at epoch  14  is:  0.6399999856948853
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0588 - binary_accuracy: 0.9850 - val_loss: 1.1299 - val_binary_accuracy: 0.6200
# Run:  3 / Accuracy on test set at epoch  15  is:  0.6200000047683716
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0427 - binary_accuracy: 0.9800 - val_loss: 1.5171 - val_binary_accuracy: 0.5600
# Run:  3 / Accuracy on test set at epoch  16  is:  0.5600000023841858
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0083 - binary_accuracy: 1.0000 - val_loss: 1.6152 - val_binary_accuracy: 0.6300
# Run:  3 / Accuracy on test set at epoch  17  is:  0.6299999952316284
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.0038 - binary_accuracy: 1.0000 - val_loss: 1.8941 - val_binary_accuracy: 0.6000
# Run:  3 / Accuracy on test set at epoch  18  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.0027 - binary_accuracy: 1.0000 - val_loss: 1.7288 - val_binary_accuracy: 0.6300
# Run:  3 / Accuracy on test set at epoch  19  is:  0.6299999952316284
#
# Accuracies over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.550000011920929, 0.5899999737739563, 0.5799999833106995, 0.5699999928474426, 0.5899999737739563, 0.6100000143051147, 0.6299999952316284, 0.6200000047683716, 0.6299999952316284, 0.6399999856948853, 0.6200000047683716, 0.5600000023841858, 0.6299999952316284, 0.6000000238418579, 0.6299999952316284]
#
# 200/200 [==============================] - 24s 109ms/step - loss: 0.7054 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test set at epoch  0  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6964 - binary_accuracy: 0.4300 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test set at epoch  1  is:  0.5
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6953 - binary_accuracy: 0.3850 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test set at epoch  2  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6948 - binary_accuracy: 0.4600 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test set at epoch  3  is:  0.5
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.6946 - binary_accuracy: 0.4550 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test set at epoch  4  is:  0.5
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6946 - binary_accuracy: 0.4450 - val_loss: 0.6930 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test set at epoch  5  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6943 - binary_accuracy: 0.4550 - val_loss: 0.6918 - val_binary_accuracy: 0.5400
# Run:  4 / Accuracy on test set at epoch  6  is:  0.5400000214576721
#
# 200/200 [==============================] - 4s 18ms/step - loss: 0.6898 - binary_accuracy: 0.5000 - val_loss: 0.6857 - val_binary_accuracy: 0.5200
# Run:  4 / Accuracy on test set at epoch  7  is:  0.5199999809265137
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6766 - binary_accuracy: 0.5550 - val_loss: 0.6866 - val_binary_accuracy: 0.5700
# Run:  4 / Accuracy on test set at epoch  8  is:  0.5699999928474426
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6502 - binary_accuracy: 0.5950 - val_loss: 0.6948 - val_binary_accuracy: 0.5800
# Run:  4 / Accuracy on test set at epoch  9  is:  0.5799999833106995
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.5995 - binary_accuracy: 0.7100 - val_loss: 0.6887 - val_binary_accuracy: 0.5600
# Run:  4 / Accuracy on test set at epoch  10  is:  0.5600000023841858
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.5328 - binary_accuracy: 0.7700 - val_loss: 0.6796 - val_binary_accuracy: 0.5800
# Run:  4 / Accuracy on test set at epoch  11  is:  0.5799999833106995
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.4094 - binary_accuracy: 0.8200 - val_loss: 0.7045 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test set at epoch  12  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2613 - binary_accuracy: 0.8950 - val_loss: 0.7958 - val_binary_accuracy: 0.6000
# Run:  4 / Accuracy on test set at epoch  13  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1762 - binary_accuracy: 0.9250 - val_loss: 0.8741 - val_binary_accuracy: 0.6000
# Run:  4 / Accuracy on test set at epoch  14  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0997 - binary_accuracy: 0.9650 - val_loss: 0.9755 - val_binary_accuracy: 0.5900
# Run:  4 / Accuracy on test set at epoch  15  is:  0.5899999737739563
#
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0466 - binary_accuracy: 0.9800 - val_loss: 1.0914 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test set at epoch  16  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0113 - binary_accuracy: 1.0000 - val_loss: 1.2955 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test set at epoch  17  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0038 - binary_accuracy: 1.0000 - val_loss: 1.5195 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test set at epoch  18  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0031 - binary_accuracy: 1.0000 - val_loss: 1.9751 - val_binary_accuracy: 0.5700
# Run:  4 / Accuracy on test set at epoch  19  is:  0.5699999928474426
#
# Accuracies over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5400000214576721, 0.5199999809265137, 0.5699999928474426, 0.5799999833106995, 0.5600000023841858, 0.5799999833106995, 0.6100000143051147, 0.6000000238418579, 0.6000000238418579, 0.5899999737739563, 0.6100000143051147, 0.6100000143051147, 0.6100000143051147, 0.5699999928474426]
#
# 200/200 [==============================] - 23s 108ms/step - loss: 0.7054 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test set at epoch  0  is:  0.5
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6965 - binary_accuracy: 0.4200 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test set at epoch  1  is:  0.5
#
# 200/200 [==============================] - 3s 15ms/step - loss: 0.6953 - binary_accuracy: 0.4150 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test set at epoch  2  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6950 - binary_accuracy: 0.4300 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test set at epoch  3  is:  0.5
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6948 - binary_accuracy: 0.4250 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test set at epoch  4  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6943 - binary_accuracy: 0.4450 - val_loss: 0.6930 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test set at epoch  5  is:  0.5
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6933 - binary_accuracy: 0.4800 - val_loss: 0.6914 - val_binary_accuracy: 0.5200
# Run:  5 / Accuracy on test set at epoch  6  is:  0.5199999809265137
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.6872 - binary_accuracy: 0.5250 - val_loss: 0.6856 - val_binary_accuracy: 0.5400
# Run:  5 / Accuracy on test set at epoch  7  is:  0.5400000214576721
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6713 - binary_accuracy: 0.5500 - val_loss: 0.6854 - val_binary_accuracy: 0.5500
# Run:  5 / Accuracy on test set at epoch  8  is:  0.550000011920929
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6408 - binary_accuracy: 0.6350 - val_loss: 0.6842 - val_binary_accuracy: 0.5900
# Run:  5 / Accuracy on test set at epoch  9  is:  0.5899999737739563
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.5803 - binary_accuracy: 0.7200 - val_loss: 0.6750 - val_binary_accuracy: 0.6000
# Run:  5 / Accuracy on test set at epoch  10  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.4879 - binary_accuracy: 0.8000 - val_loss: 0.6820 - val_binary_accuracy: 0.6100
# Run:  5 / Accuracy on test set at epoch  11  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.3628 - binary_accuracy: 0.8250 - val_loss: 0.7525 - val_binary_accuracy: 0.6000
# Run:  5 / Accuracy on test set at epoch  12  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2434 - binary_accuracy: 0.8850 - val_loss: 0.9018 - val_binary_accuracy: 0.6300
# Run:  5 / Accuracy on test set at epoch  13  is:  0.6299999952316284
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.1555 - binary_accuracy: 0.9300 - val_loss: 0.9543 - val_binary_accuracy: 0.6100
# Run:  5 / Accuracy on test set at epoch  14  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0600 - binary_accuracy: 0.9800 - val_loss: 1.0714 - val_binary_accuracy: 0.6400
# Run:  5 / Accuracy on test set at epoch  15  is:  0.6399999856948853
#
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0419 - binary_accuracy: 0.9850 - val_loss: 1.5782 - val_binary_accuracy: 0.6000
# Run:  5 / Accuracy on test set at epoch  16  is:  0.6000000238418579
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0101 - binary_accuracy: 1.0000 - val_loss: 1.6226 - val_binary_accuracy: 0.6100
# Run:  5 / Accuracy on test set at epoch  17  is:  0.6100000143051147
#
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0144 - binary_accuracy: 0.9950 - val_loss: 1.5790 - val_binary_accuracy: 0.5900
# Run:  5 / Accuracy on test set at epoch  18  is:  0.5899999737739563
#
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0055 - binary_accuracy: 1.0000 - val_loss: 1.7042 - val_binary_accuracy: 0.6500
# Run:  5 / Accuracy on test set at epoch  19  is:  0.6499999761581421
#
# Accuracies over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5199999809265137, 0.5400000214576721, 0.550000011920929, 0.5899999737739563, 0.6000000238418579, 0.6100000143051147, 0.6000000238418579, 0.6299999952316284, 0.6100000143051147, 0.6399999856948853, 0.6000000238418579, 0.6100000143051147, 0.5899999737739563, 0.6499999761581421]
#
#
#
#  Over all runs maximum accuracies on test set are: [0.6100000143051147, 0.6399999856948853, 0.6399999856948853, 0.6499999761581421, 0.6800000071525574]
# The median is: 0.6399999856948853
#
#
#
# CNN Accuracy Score on test set ->  0.6399999856948853 +/- 0.04000002145767212
